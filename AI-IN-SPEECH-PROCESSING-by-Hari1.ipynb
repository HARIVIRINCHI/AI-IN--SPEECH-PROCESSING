# %%
import librosa
import librosa.display
import matplotlib.pyplot as plot

# %%
filename = 'Hari1.wav'

# %%
import IPython.display as ipdisp

# %%
ipdisp.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
y, sr = librosa.load(filename)
librosa.display.waveshow(y)
plot.title('Speech Signal Waveform')
plot.xlabel('Time')
plot.ylabel('Amplitude') 
plot.show()

# %%
from IPython.display import Audio
start_time = 1
end_time = 4
segment = y[int(start_time * sr):int(end_time * sr)]
Audio(segment, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot.figure(figsize=(10, 4))
librosa.display.waveshow(segment, sr=sr)
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.show()

# %%
segment1 = y[:int(1 * sr)]
Audio(segment1, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot.figure(figsize=(10, 4))
librosa.display.waveshow(segment1, sr=sr)
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.show()

# %%
segment2 = y[int(1 * sr):int(2 * sr)]
Audio(segment2, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot.figure(figsize=(10, 4))
librosa.display.waveshow(segment2, sr=sr)
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.show()

# %%
segment3 = y[int(2 * sr):int(3 * sr)]
Audio(segment3, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot.figure(figsize=(10, 4))
librosa.display.waveshow(segment3, sr=sr)
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.show()

# %%
segment4 = y[int(3 * sr):int(4 * sr)]
Audio(segment4, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot.figure(figsize=(10, 4))
librosa.display.waveshow(segment4, sr=sr)
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.show()

# %%
segment5 = y[int(4 * sr):int(5 * sr)]
Audio(segment5, rate=sr)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
plot.figure(figsize=(10, 4))
librosa.display.waveshow(segment5, sr=sr)
plot.xlabel('Time')
plot.ylabel('Amplitude')
plot.show()
